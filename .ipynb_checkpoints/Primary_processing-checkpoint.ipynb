# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mid_salary_p = pd.read_csv("middle_salary_primary.csv")[["year", "mid salary, hryvnias"]]
popupation_p = pd.read_csv("population_info_primary.csv")[["year", "population (thousands)"]]

# %%
mid_salary_p
# Out:
#     year  mid salary, hryvnias
# 0   1996                125.23
# 1   1997                143.09
# 2   1998                152.83
# 3   1999                177.39
# 4   2000                231.04
# 5   2001                311.62
# 6   2002                375.98
# 7   2003                462.58
# 8   2004                590.53
# 9   2005                806.14
# 10  2006               1042.88
# 11  2007               1352.75
# 12  2008               1808.92
# 13  2009               1909.25
# 14  2010               2246.75
# 15  2011               2639.17
# 16  2012               3031.92
# 17  2013               3273.82
# 18  2014               3474.75
# 19  2015               4207.33
# 20  2016               5187.33
# 21  2017               7105.42
# 22  2018               8867.33
# 23  2019              10503.75
# 24  2020              11596.60

# %%
popupation_p
# Out:
#     year  population (thousands)
# 0   1990                 51838.5
# 1   1991                 51944.4
# 2   1992                 52056.6
# 3   1993                 52244.1
# 4   1994                 52114.4
# 5   1995                 51728.4
# 6   1996                 51297.1
# 7   1997                 50818.4
# 8   1998                 50370.8
# 9   1999                 49918.1
# 10  2000                 49429.8
# 11  2001                 48923.2
# 12  2002                 48457.1
# 13  2003                 48003.5
# 14  2004                 47622.4
# 15  2005                 47280.8
# 16  2006                 46929.5
# 17  2007                 46646.0
# 18  2008                 46372.7
# 19  2009                 46143.7
# 20  2010                 45962.9
# 21  2011                 45778.5
# 22  2012                 45633.6
# 23  2013                 45553.0
# 24  2014                 45426.2
# 25  2015                 42928.9
# 26  2016                 42760.5
# 27  2017                 42584.5
# 28  2018                 42386.4
# 29  2019                 42153.2
# 30  2020                 41902.4
# 31  2021                 41588.4
# 32  2022                 41167.3

# %% [markdown]
# Data primary preprocessing.

# %%
population = popupation_p[popupation_p["year"]>=1996]
population.head()
# Out:
#     year  population (thousands)
# 6   1996                 51297.1
# 7   1997                 50818.4
# 8   1998                 50370.8
# 9   1999                 49918.1
# 10  2000                 49429.8

# %%
salaries = mid_salary_p["mid salary, hryvnias"].to_list()

# %%
plt.plot(mid_salary_p["year"], mid_salary_p["mid salary, hryvnias"])
plt.show()

# %% [markdown]
# Now we try to predict mid salary in 2021 and 2022 years using parsed data.

# %%
n = len(salaries)
X = pd.DataFrame([ salaries[i:i+3] for i in range(n-3+1) ][1:])
y = pd.Series(salaries[3:])

# %%
X
# Out:
#           0         1         2
# 0    143.09    152.83    177.39
# 1    152.83    177.39    231.04
# 2    177.39    231.04    311.62
# 3    231.04    311.62    375.98
# 4    311.62    375.98    462.58
# 5    375.98    462.58    590.53
# 6    462.58    590.53    806.14
# 7    590.53    806.14   1042.88
# 8    806.14   1042.88   1352.75
# 9   1042.88   1352.75   1808.92
# 10  1352.75   1808.92   1909.25
# 11  1808.92   1909.25   2246.75
# 12  1909.25   2246.75   2639.17
# 13  2246.75   2639.17   3031.92
# 14  2639.17   3031.92   3273.82
# 15  3031.92   3273.82   3474.75
# 16  3273.82   3474.75   4207.33
# 17  3474.75   4207.33   5187.33
# 18  4207.33   5187.33   7105.42
# 19  5187.33   7105.42   8867.33
# 20  7105.42   8867.33  10503.75
# 21  8867.33  10503.75  11596.60

# %%
y
# Out:
# 0       177.39
# 1       231.04
# 2       311.62
# 3       375.98
# 4       462.58
# 5       590.53
# 6       806.14
# 7      1042.88
# 8      1352.75
# 9      1808.92
# 10     1909.25
# 11     2246.75
# 12     2639.17
# 13     3031.92
# 14     3273.82
# 15     3474.75
# 16     4207.33
# 17     5187.33
# 18     7105.42
# 19     8867.33
# 20    10503.75
# 21    11596.60
# dtype: float64

# %%
from sklearn.neural_network import MLPRegressor
from sklearn import metrics

# %%
print(f"{len(X)}\n{len(y)}")
# Out:
# 22
# 22

# %%
mlp_model = MLPRegressor((5, 25, 50, 75, 50, 25, 75, 50, 25, 5), activation="relu").fit(X, y)
pred = mlp_model.predict(X)
metrics.mean_squared_error(y, pred)
# Out:
# 20108.987500233077

# %%
plt.plot(mid_salary_p["year"], mid_salary_p["mid salary, hryvnias"])
plt.plot(mid_salary_p["year"][3:], pred)
plt.show()

# %%
predict = mlp_model.predict(pd.DataFrame([ salaries[i:i+3] for i in range(n-3+1) ][-2:]))
predict
# Out:
# array([10299.90461103, 11179.25120328])

# %%
predict += abs(y.to_list()[-1]-pred.tolist()[-1])*np.ones(2)
predict
# Out:
# array([11551.95100118, 12431.29759343])

# %%
mid_salary = pd.DataFrame()
mid_salary["year"] = mid_salary_p["year"].to_list() + [2021, 2022]
mid_salary["mid salary, hryvnias"] = mid_salary_p["mid salary, hryvnias"].to_list() + [int(v*100)/100 for v in predict]
mid_salary
# Out:
#     year  mid salary, hryvnias
# 0   1996                125.23
# 1   1997                143.09
# 2   1998                152.83
# 3   1999                177.39
# 4   2000                231.04
# 5   2001                311.62
# 6   2002                375.98
# 7   2003                462.58
# 8   2004                590.53
# 9   2005                806.14
# 10  2006               1042.88
# 11  2007               1352.75
# 12  2008               1808.92
# 13  2009               1909.25
# 14  2010               2246.75
# 15  2011               2639.17
# 16  2012               3031.92
# 17  2013               3273.82
# 18  2014               3474.75
# 19  2015               4207.33
# 20  2016               5187.33
# 21  2017               7105.42
# 22  2018               8867.33
# 23  2019              10503.75
# 24  2020              11596.60
# 25  2021              11551.95
# 26  2022              12431.29

# %%
population.index = range(len(population))
population
# Out:
#     year  population (thousands)
# 0   1996                 51297.1
# 1   1997                 50818.4
# 2   1998                 50370.8
# 3   1999                 49918.1
# 4   2000                 49429.8
# 5   2001                 48923.2
# 6   2002                 48457.1
# 7   2003                 48003.5
# 8   2004                 47622.4
# 9   2005                 47280.8
# 10  2006                 46929.5
# 11  2007                 46646.0
# 12  2008                 46372.7
# 13  2009                 46143.7
# 14  2010                 45962.9
# 15  2011                 45778.5
# 16  2012                 45633.6
# 17  2013                 45553.0
# 18  2014                 45426.2
# 19  2015                 42928.9
# 20  2016                 42760.5
# 21  2017                 42584.5
# 22  2018                 42386.4
# 23  2019                 42153.2
# 24  2020                 41902.4
# 25  2021                 41588.4
# 26  2022                 41167.3

# %%
mid_salary.to_csv("mid_salary.csv")
population.to_csv("population.csv")
